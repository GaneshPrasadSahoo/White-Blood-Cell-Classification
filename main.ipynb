# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
import zipfile

# %%
z=zipfile.ZipFile(r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\archive (53).zip")
z.extractall()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 z=zipfile.ZipFile(r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\archive (53).zip")
# ----> 2 z.extractall()
#
# File c:\Users\Ganesh prasad sahoo\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:1744, in ZipFile.extractall(self, path, members, pwd)
#    1741     path = os.fspath(path)
#    1743 for zipinfo in members:
# -> 1744     self._extract_member(zipinfo, path, pwd)
#
# File c:\Users\Ganesh prasad sahoo\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:1802, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1798     return targetpath
#    1800 with self.open(member, pwd=pwd) as source, \
#    1801      open(targetpath, "wb") as target:
# -> 1802     shutil.copyfileobj(source, target)
#    1804 return targetpath
#
# ...

# %%
# Rename All Image in folder

# %%
import os

folder = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Basophil"
count = 1

for filename in os.listdir(folder):
    source = os.path.join(folder, filename)
    destination = os.path.join(folder, f"basophil_{count}.jpg")
    os.rename(source, destination)
    count += 1
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 9
#       7 source = os.path.join(folder, filename)
#       8 destination = os.path.join(folder, f"basophil_{count}.jpg")
# ----> 9 os.rename(source, destination)
#      10 count += 1
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Ganesh prasad sahoo\\OneDrive\\Documents\\Downloads\\All DataSet\\White_blood_cells_classification\\Train\\Basophil\\20190526_162951_0.jpg' -> 'C:\\Users\\Ganesh prasad sahoo\\OneDrive\\Documents\\Downloads\\All DataSet\\White_blood_cells_classification\\Train\\Basophil\\basophil_1.jpg'

# %%
import os

folder = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Eosinophil"
count = 1

for filename in os.listdir(folder):
    source = os.path.join(folder, filename)
    destination = os.path.join(folder, f"Eosinophil_{count}.jpg")
    os.rename(source, destination)
    count += 1
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 9
#       7 source = os.path.join(folder, filename)
#       8 destination = os.path.join(folder, f"Eosinophil_{count}.jpg")
# ----> 9 os.rename(source, destination)
#      10 count += 1
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Ganesh prasad sahoo\\OneDrive\\Documents\\Downloads\\All DataSet\\White_blood_cells_classification\\Train\\Eosinophil\\95-5-10-1_1057_1.jpg' -> 'C:\\Users\\Ganesh prasad sahoo\\OneDrive\\Documents\\Downloads\\All DataSet\\White_blood_cells_classification\\Train\\Eosinophil\\Eosinophil_1.jpg'

# %%
import os

folder = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Lymphocyte"
count = 1

for filename in os.listdir(folder):
    source = os.path.join(folder, filename)
    destination = os.path.join(folder, f"Lymphocyte_{count}.jpg")
    os.rename(source, destination)
    count += 1

# %%
import os

folder = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Monocyte"
count = 1

for filename in os.listdir(folder):
    source = os.path.join(folder, filename)
    destination = os.path.join(folder, f"Monocyte_{count}.jpg")
    os.rename(source, destination)
    count += 1

# %%
import os

folder = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Neutrophil"
count = 1

for filename in os.listdir(folder):
    source = os.path.join(folder, filename)
    destination = os.path.join(folder, f"Neutrophil_{count}.jpg")
    os.rename(source, destination)
    count += 1

# %%
import os

folder = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Basophil"
total_basophil = os.listdir(folder)
number_image1 = len(total_basophil)
print("Total images present in Basophil: " + str(number_image1))

folder=r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Eosinophil"
total_eos=os.listdir(folder)
number_img2=len(total_eos)
print("total Eosinophoil image is"+str(number_img2))

folder=r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Lymphocyte"
total_Lymp=os.listdir(folder)
number_img3=len(total_Lymp)
print("total Lymphocyte image is"+str(number_img3))



folder = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Monocyte"
total_Monocyte = os.listdir(folder)
number_img4 = len(total_Monocyte)
print("Total Monocyte images: " + str(number_img4))

folder=r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Neutrophil"
total_img=os.listdir(folder)
number_img5=len(total_img)
print("Toital Neutrophil imahge"+str(number_img5))



#Total image
print("Total images in MyFolder is: " + str(number_image1 + number_img2 + number_img3 + number_img4 + number_img5))
# Out:
# Total images present in Basophil: 212
# total Eosinophoil image is744
# total Lymphocyte image is2427
# Total Monocyte images: 561
# Toital Neutrophil imahge6231
# Total images in MyFolder is: 10175

# %%
import cv2
import os
import numpy as np
from sklearn.utils import shuffle 
from sklearn.model_selection import train_test_split

# Define image size and labels
img_size = 150
labels = ["Basophil", "Eosinophil", "Lymphocyte", "Monocyte", "Neutrophil"]

# Initialize lists for training and test data
x_train = []
y_train = []
x_test = []
y_test = []

# Load training data
for label in labels:
    folderpath = os.path.join(r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train", label)
    
    for filename in os.listdir(folderpath):
        img_path = os.path.join(folderpath, filename)
        img = cv2.imread(img_path)
        
        if img is not None:
            img = cv2.resize(img, (img_size, img_size))
            x_train.append(img)
            y_train.append(label)

# Load test data
for label in labels:
    folderpath = os.path.join(r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Test-A", label)
    
    for filename in os.listdir(folderpath):
        img_path = os.path.join(folderpath, filename)
        img = cv2.imread(img_path)
        
        if img is not None:
            img = cv2.resize(img, (img_size, img_size))
            x_test.append(img)
            y_test.append(label)

# Convert lists to numpy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
from sklearn.utils import shuffle

x_train,y_train=shuffle(x_train,y_train,random_state=100)
x_train.shape
# Out:
# (14514, 150, 150, 3)

# %%
from sklearn.model_selection import train_test_split

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=100)


print("x_train shape:", x_train.shape)
print("x_val shape:", x_val.shape)
print("x_test shape:", x_test.shape)
# Out:
# x_train shape: (6512, 150, 150, 3)
# x_val shape: (1628, 150, 150, 3)
# x_test shape: (4339, 150, 150, 3)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))  # Convert string labels to integer labels
y_train = y_train_new
y_train = tf.keras.utils.to_categorical(y_train)  # Convert integer labels to one-hot encoding

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))  # Convert string labels to integer labels
y_test = y_test_new
y_test = tf.keras.utils.to_categorical(y_test)  # Convert integer labels to one-hot encoding
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 3
#       1 y_train_new = []
#       2 for i in y_train:
# ----> 3     y_train_new.append(labels.index(i))  # Convert string labels to integer labels
#       4 y_train = y_train_new
#       5 y_train = tf.keras.utils.to_categorical(y_train)  # Convert integer labels to one-hot encoding
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
print(y_test[0])
# Out:
# [1. 0. 0. 0. 0.]

# %%
print(y_train[1])
# Out:
# [1. 0. 0. 0. 0.]

# %%
plt.imshow(x_train[5000])

# %%
plt.imshow(x_train[2340])

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout
from sklearn.metrics import accuracy_score

import ipywidgets as widgets
import io
from PIL import Image
from sklearn.model_selection import train_test_split
import cv2
from sklearn.utils import shuffle
import tensorflow as tf

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation = 'relu',input_shape=(150,150,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512,activation = 'relu'))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(5,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 146, 146, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 71, 71, 64)     │        36,928 │
# ...

# %%
model.compile(
    loss='categorical_crossentropy',  # Loss function for multi-class classification with one-hot encoded labels
    optimizer='adam',                 # Optimizer (note: 'Adam' should be in lowercase 'adam')
    metrics=['accuracy']              # Metrics to evaluate during training
)

# %%
history = model.fit(
    x_train,            
    y_train,           
    epochs=5,         
    validation_split=0.1,  
    batch_size=32       
)
# Out:
# Epoch 1/5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 369s 1s/step - accuracy: 0.5888 - loss: 1.0583 - val_accuracy: 0.8821 - val_loss: 0.3726
# Epoch 2/5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 355s 1s/step - accuracy: 0.8710 - loss: 0.3637 - val_accuracy: 0.9126 - val_loss: 0.3475
# Epoch 3/5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 353s 1s/step - accuracy: 0.9000 - loss: 0.2862 - val_accuracy: 0.7780 - val_loss: 0.8387
# Epoch 4/5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 364s 1s/step - accuracy: 0.8808 - loss: 0.3280 - val_accuracy: 0.8664 - val_loss: 0.7006
# Epoch 5/5
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 375s 1s/step - accuracy: 0.9217 - loss: 0.2308 - val_accuracy: 0.8703 - val_loss: 0.4876

# %%
acc=history.history["accuracy"]
val_acc = history.history['val_accuracy']
epochs = range(len(acc))
fig = plt.figure(figsize=(14,7))
plt.plot(epochs,acc,'r',label="Training Accuracy")
plt.plot(epochs,val_acc,'b',label="Validation Accuracy")
plt.legend(loc='upper left')
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(loss))
fig = plt.figure(figsize=(14,7))
plt.plot(epochs,loss,'r',label="Training loss")
plt.plot(epochs,val_loss,'b',label="Validation loss")
plt.legend(loc='upper left')
plt.show()

# %%
from PIL import Image

# %% [markdown]
# Lets predict here

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image  # Correct import for image loading
from tensorflow.keras.models import load_model  # To load a pre-trained model

# Define image path
img_path = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Eosinophil\Eosinophil_742.jpg"

# Read and preprocess the image
img = cv2.imread(img_path)
img = cv2.resize(img, (150, 150))  
img_array = np.array(img)
img_array = img_array.reshape(1, 150, 150, 3)  # Reshape to add batch dimension

# Load and display the image using matplotlib
img_to_display = image.load_img(img_path)
plt.imshow(img_to_display, interpolation='nearest')
plt.show()


a = model.predict(img_array)  
indices = a.argmax()  

# Labels for the prediction
labels = ["Basophil", "Eosinophil", "Lymphocyte", "Monocyte", "Neutrophil"]

# Display the predicted label
predicted_label = labels[indices]
print(f"Predicted Label: {predicted_label}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      18 plt.imshow(img_to_display, interpolation='nearest')
#      19 plt.show()
# ---> 22 a = model.predict(img_array)
#      23 indices = a.argmax()
#      25 # Labels for the prediction
#
# NameError: name 'model' is not defined

# %%
model.save("whiteblood.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import cv2

img = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Eosinophil\95-5-4-1_16_1.jpg"
img = cv2.imread(i
cv2.imshow("medical image", img) 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import tensorflow as tf

# Load the trained model
model_path = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\whiteblood.h5"
model = tf.keras.models.load_model(model_path)

print("✅ Model loaded successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded successfully!

# %%
import cv2
import numpy as np

def preprocess_image(image_path):
    img = cv2.imread(image_path) 
    img = cv2.resize(img, (150, 150)) 
    img = img / 255.0  
    img = np.expand_dims(img, axis=0) 
    return img

# %%
# Path to the test image
test_image_path = r"C:\Users\Ganesh prasad sahoo\OneDrive\Documents\Downloads\All DataSet\White_blood_cells_classification\Train\Lymphocyte\95-5-4-1_6_2.jpg"# Replace with the actual path

# Preprocess the image
processed_img = preprocess_image(test_image_path)

# Make a prediction
prediction = model.predict(processed_img)

# Get the predicted class index
predicted_class = np.argmax(prediction)

# Define class labels (Update according to your dataset)
class_labels = ["Neutrophil", "Eosinophil", "Basophil", "Lymphocyte", "Monocyte"]

print(f"🧪 Predicted White Blood Cell Type: {class_labels[predicted_class]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5 processed_img = preprocess_image(test_image_path)
#       7 # Make a prediction
# ----> 8 prediction = model.predict(processed_img)
#      10 # Get the predicted class index
#      11 predicted_class = np.argmax(prediction)
#
# NameError: name 'model' is not defined
